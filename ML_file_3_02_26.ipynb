# %% [markdown]
# <a href="https://colab.research.google.com/github/khushivats0201/Machine-learning-/blob/main/ML_file_3_02_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

x = np.array([1,3,5,7,8,9, 10, 15])
y = np.array([10, 20, 30, 40, 50, 60, 70, 80])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
# Out:
# 0.974894414261588
# 1.0

# %%
x1 = np.array([1,3,5,7,8,9, 10, 15])
y1 = np.array([80,70,60,50,40,30,20,10])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
# Out:
# -0.974894414261588
# 1.0

# %%
x2 = np.array([1,3,5,7,8,9, 10, 15])
y2 = np.array([20,10,80,70,40,30,50,60])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x2,y2))
print(Pearson_correlation(x2,x2))
# Out:
# 0.4273509761146687
# 1.0

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/insurance2.csv')
corr = df.corr(method = 'pearson')
corr
print(corr)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000
